# %%
from multiprocessing import Pool
import os

def safe_readline(f):
    pos = f.tell()  # 
    while True:
        try:
            return f.readline()
        except UnicodeDecodeError:
            pos -= 1
            f.seek(pos) 


def async_tokenizer(filename, worker_id, num_workers):
#     print(f'worker_id = {worker_id}')
    with open(filename, 'r') as f:
        size = os.fstat(f.fileno()).st_size
        chunk_size = size // num_workers
        offset = worker_id * chunk_size
        end = offset + chunk_size
        f.seek(offset)
        if offset > 0:
            safe_readline(f)  # drop first incomplete line
        encoded = []
        line = f.readline()
        while line:
            print(f'word id {worker_id} line = {line}')
            encoded.append(line)
            if f.tell() > end:
                break
            line = f.readline()
        return encoded

    
def read_file(path, workers=4):
        encoded = []
        workers_thread = []
        pool = Pool(processes=workers)
        for i in range(workers):
            w = pool.apply_async(
                    async_tokenizer,
                    (
                        path,
                        i,
                        workers,
                    ),
                )
            workers_thread.append(w)
        pool.close()
        pool.join()
        for w in workers_thread:
            result = w.get()
            encoded += result
        return encoded
    
    
path = '../test_data/small.valid.txt'
results = read_file(path, 4)
# Out:
# word id 0 line = 2	标题	：	 0	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	咳咳，都在啊？	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	为什么不行	[unused41]
# word id 3 line = 16	乔南辰	：	宝贝儿变成什么样都是我的心头肉	[unused41]
#
#
#
#
# word id 0 line = 1	旁白	：	唐志承来了……	[unused41]
# word id 2 line = 16	乔南辰	：	够了	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	吴梁，你打电话是什么情况啊	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	(翻白眼)乔南辰，你够了行不行？	[SEP]	我都想吐了	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	咳咳	[SEP]	晚上你们要干嘛去	[unused41]
#
# word id 2 line = 17	夏玖晞	：	你们平静下	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	哈喽	[unused41]
#
# word id 3 line = 16	乔南辰	：	吐呗！这些天你天天在微博跟鹿迪秀恩爱，这次该我们了	[unused41]
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	鹿迪没和你说？	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	鹿迪，你刚才说的是真的吗？	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	抱歉来晚了	[unused41]
#
# word id 3 line = 17	夏玖晞	：	哈哈哈	[unused41]
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	他和老大说了，没和我们说	[unused41]
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	我们也刚到	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	嗯？	[unused41]
#
#
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	玖晞，几个月了？	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	😂	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	吴梁你现在可以说了吧？	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	就是咱俩在一起办婚礼，你们出你们的我们出我们的	[unused41]
#
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	大嫂，你干啥	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	嗯	[SEP]	内个我想做明星	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	真的呢，你又不愿意人家万琳有不结婚了你问这个干什么？	[unused41]
# word id 3 line = 17	夏玖晞	：	九个月了	[unused41]
#
#
# word id 0 line = 5	【学姐】夏沫歌	：	大嫂？	[unused41]
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	那你要注意一点	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	……	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	对啊	[unused41]
#
#
#
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	吴梁不来吗？	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	……	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[脸红]……唐志……唐志承你好	[unused41]
#
#
# word id 3 line = 16	乔南辰	：	一会儿就来了	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	……	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	你好，万琳	[unused41]
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	……	[unused41]
# word id 3 line = 17	夏玖晞	：	倩倩，我们坐下聊吧	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[脸红]嗯，师兄你好	[unused41]
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	……	[unused41]
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯好	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	噗	[unused41]
#
#
#
# word id 3 line = 17	夏玖晞	：	芸汐，妍熙呢？	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	……	[unused41]
# word id 1 line = 17	夏玖晞	：	吴梁，你没事吧？	[unused41]
#
#
#
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	墨墨，抱去房间玩了	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我受不了了	[SEP]	我先走一步	[unused41]
# word id 1 line = 16	乔南辰	：	。。你为什么会选择当明星了	[unused41]
#
#
#
# word id 0 line = 5	【学姐】夏沫歌	：	回来	[unused41]
# word id 3 line = 17	夏玖晞	：	咳，好的	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	是真的，前几天我被一个导演看中了	[unused41]
#
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我……	[unused41]
# word id 1 line = 16	乔南辰	：	真的吗？	[unused41]
#
# word id 3 line = 16	乔南辰	：	你们聊，我出去一下	[unused41]
#
# word id 0 line = 5	【学姐】夏沫歌	：	等会吴梁	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	是啊	[unused41]
#
# word id 3 line = 17	夏玖晞	：	嗯嗯，早点回来	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我……	[unused41]
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	我没有听错吧？	[SEP]	吴梁要做明星？	[unused41]
#
#
# word id 3 line = 16	乔南辰	：	好。	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	好了乖	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	你没听错	[unused41]
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	你这几个月都挺好的吧	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	沫歌你别搭理他们	[unused41]
#
#
#
# word id 1 line = 17	夏玖晞	：	真好，你要加油哦	[unused41]
# word id 3 line = 17	夏玖晞	：	挺好啊	[SEP]	倒是你，你和吴梁……	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	哈哈哈	[unused41]
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	嗯，不过南辰你帮我找个助理呗	[unused41]
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	唐志承	[unused41]
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	芸汐，你最近还上班吗？	[unused41]
# word id 1 line = 17	夏玖晞	：	我有个人没工作，不知道你要不要？	[unused41]
#
#
#
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	不上了	[SEP]	我都在专心在家看闺女	[SEP]	鹿迪出去上班就行了	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	嗯？	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	男的女的？	[unused41]
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	你这几天没少欺负人家鹿迪吧？	[unused41]
#
# word id 1 line = 17	夏玖晞	：	女的	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	我要是说有人喜欢你，你信吗？	[unused41]
#
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	哪有怎样	[SEP]	哼	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	是谁？	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	芸汐你干啥	[unused41]
#
# word id 1 line = 17	夏玖晞	：	远在天边，近在眼前	[unused41]
#
# word id 3 line = 17	夏玖晞	：	夫妻之间要好好的	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	闭嘴	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	。。。不是你吧？	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	谁啊？谁喜欢我	[SEP]	莫非是你？那可不行你是我兄弟的女朋友	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	知道。	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	噗	[unused41]
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	屁，谁说我喜欢你了	[SEP]	我的意思是，这个人你也认识	[unused41]
# word id 3 line = 17	夏玖晞	：	琳琳没和你们一起来吗？	[unused41]
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	谁说她不结婚的	[SEP]	她说的是气话	[unused41]
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	怎么了？	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	什么	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	她跟唐志承一起来	[SEP]	所以没和我俩一起	[unused41]
#
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	玖晞的意思是，你身边林倩倩很合适	[unused41]
# word id 3 line = 17	夏玖晞	：	这样啊	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	我们有两个人喜欢你只有一个	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	哦谁啊？	[SEP]	大嫂	[unused41]
# word id 3 line = 1	旁白	：	不过多久唐志承万琳还有吴梁跟着雪莹思一起来了。。	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	我？	[unused41]
#
#
#
# word id 3 line = 13	乔逸晨哥们【吴梁】	：	大家好啊	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	对啊	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	我不知道	[unused41]
#
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我也不知道	[unused41]
# word id 1 line = 17	夏玖晞	：	吴梁，你觉得呢？	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	好	[SEP]	鹿迪人呢？	[unused41]
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	你凭什么自己认为我说的是气话	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	就是啊，你凭什么这样认为呢？	[unused41]
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	莫芸汐，你可以不插话？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	我？	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	唐志承	[SEP]	你他么的冲我可以，别冲我女人	[SEP]	她是我女人，不是你的发泄工具	[unused41]
#
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	你们同意吗？	[unused41]
# word id 3 line = 3	乔逸晨哥们【唐志承】	：	没见他	[SEP]	我以为他跟你一起来了	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[无语]你们要做什么	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	唐志承，说我闺蜜还轮不到你吧？	[unused41]
#
#
#
# word id 1 line = 16	乔南辰	：	无话可说	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	我知道了，该不会是你吧？万琳	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	没有啊	[unused41]
# word id 2 line = 16	乔南辰	：	够了	[SEP]	有完没完？	[SEP]	吵完了没？	[SEP]	要么一起办要么一起滚	[unused41]
#
#
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	我也赞同	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	说不定在路上呢	[unused41]
# word id 2 line = 17	夏玖晞	：	唐志承你说话太冲了	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	嗯是	[unused41]
#
#
#
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	我刚才失态了，抱歉	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	也许吧	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	同意	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	姐，这是万琳吗？	[unused41]
#
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	南辰，我们一起办。	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	同意	[unused41]
# word id 3 line = 23	雪莹思	：	你们好	[unused41]
#
# word id 0 line = 5	【学姐】夏沫歌	：	是啊	[unused41]
#
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯对一起	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	倩倩，你怎么想的	[unused41]
# word id 3 line = 17	夏玖晞	：	你是？	[unused41]
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	是的	[unused41]
#
# word id 2 line = 17	夏玖晞	：	琳琳？	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	我……我	[unused41]
#
# word id 3 line = 23	雪莹思	：	我是雪莹思，吴梁的女朋友	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	这……也太内个啥了	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	当然一起	[unused41]
# word id 1 line = 17	夏玖晞	：	没事，如果你喜欢就说	[unused41]
#
#
#
#
# word id 2 line = 16	乔南辰	：	唐志承你呢？	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯，我同意	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	……	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	哈哈哈	[unused41]
#
#
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	好呢	[SEP]	以后，我就是你的老板	[unused41]
# word id 3 line = 4	夏沫歌闺蜜【莫芸汐】	：	……	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	我……一起就一起吧	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	嗯	[SEP]	那好	[unused41]
# word id 3 line = 17	夏玖晞	：	……	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	咳	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	我呸	[unused41]
#
#
#
#
# word id 2 line = 17	夏玖晞	：	你们打算什么时候办婚礼？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	我是喜欢你，我不知道你……	[unused41]
# word id 1 line = 17	夏玖晞	：	哈哈哈哈	[unused41]
# word id 3 line = 3	乔逸晨哥们【唐志承】	：	吴梁，这……这你女朋友？	[unused41]
#
#
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	玖晞，墨墨什么时候生日？	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	[偷笑]你喜欢我？不是为了接近乔逸晨吧？	[unused41]
# word id 3 line = 13	乔逸晨哥们【吴梁】	：	是啊	[unused41]
#
# word id 1 line = 16	乔南辰	：	媳妇，你什么时候走？	[unused41]
#
# word id 2 line = 16	乔南辰	：	五月二十	[unused41]
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	走？	[SEP]	是什么意思？	[unused41]
#
# word id 3 line = 1	旁白	：	在场的人目光转向林倩倩，就是想知道林倩倩是什么反应	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	[惊呆]……	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	不如在墨墨的生日那天办婚礼吧？	[SEP]	也当是给他的生日礼物	[unused41]
#
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	[惊呆]……	[unused41]
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	你们看我干什么？	[SEP]	我脸上写着字？	[unused41]
# word id 1 line = 17	夏玖晞	：	我去美国参加三年的设计师培训	[unused41]
#
# word id 2 line = 17	夏玖晞	：	，这个礼物太重了	[unused41]
#
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	[惊呆]……	[unused41]
# word id 2 line = 16	乔南辰	：	不重挺好	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	哦哦	[unused41]
#
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	你……你在胡说什么	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	我也觉得挺好	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	没……没有	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	三年太长了吧？	[unused41]
#
#
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	就这样呗	[unused41]
# word id 1 line = 17	夏玖晞	：	没有办法	[SEP]	听我哥说，到了哪里后还不能联系	[SEP]	怕影响	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	就是啊！唐志承你别乱说	[unused41]
# word id 3 line = 3	乔逸晨哥们【唐志承】	：	没有啊！就是看看	[unused41]
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	也算是我们给他人生中第一次的生日礼物	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	我没有哦，不然	[SEP]	不然你们为什么喜欢乔逸身边的人	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	嗯嗯	[unused41]
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	莫名其妙的	[SEP]	玖晞，家里有酒吗？我想喝酒	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	那学长咋办？	[unused41]
#
# word id 2 line = 17	夏玖晞	：	我替墨墨，谢谢你们啦	[unused41]
#
#
#
# word id 1 line = 17	夏玖晞	：	他在海城喽	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	唐志承	[SEP]	老子给你没完	[SEP]	敢说我姐们，找死	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	没事呢	[unused41]
# word id 3 line = 13	乔逸晨哥们【吴梁】	：	你不是不能喝酒吗？	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	话说吴梁呢？	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	你不怕他让我们拐走？	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	不怕呢	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	行行，开玩笑	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[生气]哼	[unused41]
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	呵……我喝酒管你毛事	[SEP]	你谁啊	[unused41]
#
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	他带着倩倩去拍戏了	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	林倩倩	[SEP]	玖晞怀着孕呢，别喝酒	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	你心够大	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	你喜欢我哪里？	[unused41]
#
# word id 3 line = 7	夏沫歌闺蜜【林倩倩】	：	哦！对玖晞怀着孕呢	[unused41]
# word id 2 line = 17	夏玖晞	：	他拍戏了？	[unused41]
#
# word id 1 line = 17	夏玖晞	：	反正我们结婚了	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	……	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯	[unused41]
# word id 1 line = 16	乔南辰	：	😂😂	[unused41]
#
# word id 3 line = 17	夏玖晞	：	内个大家坐下聊	[unused41]
#
# word id 0 line = 5	【学姐】夏沫歌	：	……	[unused41]
#
#
#
# word id 2 line = 17	夏玖晞	：	那你们的婚礼他们……	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	学长，你老婆厉害	[unused41]
# word id 3 line = 23	雪莹思	：	初次见到大家，还请多多关照	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	……	[unused41]
#
#
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	是的，参加不了	[unused41]
# word id 3 line = 17	夏玖晞	：	嗯	[unused41]
# word id 1 line = 16	乔南辰	：	夸奖	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	……	[unused41]
#
#
#
#
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	老公，给我倒杯水可以吗？	[unused41]
# word id 2 line = 16	乔南辰	：	他在哪拍戏？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[生气]我不喜欢了	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	哎！明星也不好当啊	[unused41]
#
#
#
# word id 1 line = 17	夏玖晞	：	人生就是如此	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	浙江	[unused41]
#
# word id 3 line = 3	乔逸晨哥们【唐志承】	：	好，等着	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	唐志承你完蛋了	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	大嫂，那你三年后能回来吗？	[unused41]
# word id 2 line = 16	乔南辰	：	那为什么不去浙江办婚礼？	[unused41]
#
#
#
#
# word id 3 line = 23	雪莹思	：	万琳姐，你老公对你真好	[unused41]
# word id 1 line = 17	夏玖晞	：	怎么这么说？	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	对哦！换个城市办婚礼，心情也好多	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	啥？	[unused41]
#
#
# word id 3 line = 6	夏沫歌闺蜜【万琳】	：	是啊，挺好	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	我怕你习惯在哪里的生活	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	可以的	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	你真的惹怒了她	[unused41]
# word id 3 line = 13	乔逸晨哥们【吴梁】	：	莹思，你想喝什么吗？	[unused41]
#
# word id 1 line = 17	夏玖晞	：	噗，谁说我不会回来的	[SEP]	你们在哪我就在哪	[unused41]
#
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	这样，吴梁也能参加我们的婚礼了	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	我就是开玩笑而已啊	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	你说的啊	[SEP]	南辰，大嫂说的	[unused41]
# word id 3 line = 23	雪莹思	：	不喝，我想跟大家聊会儿天	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	嗯	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	你开大了	[unused41]
# word id 1 line = 16	乔南辰	：	我耳朵没聋	[unused41]
#
#
#
#
# word id 3 line = 13	乔逸晨哥们【吴梁】	：	好，想喝什么就说	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	确实	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	呃	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	哦对了，后天一个叫宋羽洛想约一下你，你看？	[unused41]
#
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	那我……怎么办	[unused41]
# word id 1 line = 17	夏玖晞	：	我估计通知书应该下来了	[unused41]
# word id 2 line = 16	乔南辰	：	女的？	[unused41]
# word id 3 line = 23	雪莹思	：	我知道啦！亲爱的	[unused41]
#
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	下来就走？	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	嗯	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	你去……	[unused41]
# word id 3 line = 1	旁白	：	...	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	找我干什么？	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	咳咳	[SEP]	唐志承，人家喜欢你被你这样说，找我我也会和你生气的	[unused41]
# word id 1 line = 17	夏玖晞	：	我也不确定	[unused41]
#
#
#
# word id 3 line = [EOP]
# word id 1 line = 16	乔南辰	：	正好，我借着三年的机会管理下公司	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	那我怎么做啊	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	不知道，你见不见	[unused41]
#
# word id 1 line = 17	夏玖晞	：	嗯，老公，要给我留个位置	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	看你自己喽	[unused41]
# word id 3 line = 2	标题	：	 0	[unused41]
#
#
#
#
# word id 2 line = 17	夏玖晞	：	南辰，她是谁？	[unused41]
# word id 3 line = 1	旁白	：	三人成功到达夏家	[SEP]	林倩倩快速的到了客厅哭着跪在沫歌父母前	[SEP]	李文君和许雅婷也快速的跟着林倩倩	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	你放心啦	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	好吧	[unused41]
# word id 2 line = 16	乔南辰	：	一个同学	[unused41]
# word id 3 line = 3	乔南辰	：	李文君，许文婷你两怎么来了	[unused41]
#
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	什么位子？	[unused41]
# word id 0 line = 5	【学姐】夏沫歌	：	我们相信你	[unused41]
# word id 2 line = 17	夏玖晞	：	哦哦	[unused41]
#
#
#
#
# word id 3 line = 4	慕熠凤	：	你认识？	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	她现在也是演艺圈的人了，好像是通过吴梁找到你的	[unused41]
#
# word id 3 line = 3	乔南辰	：	我们同学	[unused41]
#
# word id 3 line = 5	夏沫歌闺蜜【万琳】	：	倩倩，你怎么了	[SEP]	为什么哭	[unused41]
#
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	叔叔……阿姨	[SEP]	我……	[SEP]	我……	[SEP]	沫歌她安全了	[unused41]
#
# word id 3 line = 7	夏玖晞妈妈	：	看向倩倩:你说什么？	[SEP]	我女儿安全了？	[unused41]
#
# word id 3 line = 3	乔南辰	：	人在哪	[SEP]	告诉我快	[unused41]
#
#
# word id 3 line = 8	神秘女子	：	不见了	[unused41]
#
# word id 3 line = 3	乔南辰	：	什么叫不见了	[SEP]	说明白	[unused41]
#
# word id 1 line = 16	乔南辰	：	设计师总监	[unused41]
# word id 3 line = 9	许雅婷	：	她让我转告你们，她对不起你们 她不孝很多很多的话，还让我转告学长，说她很爱你真的很爱你	[unused41]
#
# word id 2 line = 16	乔南辰	：	嗯	[SEP]	后天，要是没空麻烦帮我拒绝吧，理由你们随便	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	傻女人我不管她发生什么事 我一直爱她啊	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	……哦哦	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	那我要是弄不好咋办？	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	可是……她说让我们勿念！她去我们找不到她的地方	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	乔南辰，你让我刷新了对你的认识	[unused41]
#
#
#
# word id 3 line = 7	夏玖晞妈妈	：	南辰，我要见玖晞帮我找到她拜托	[unused41]
# word id 2 line = 16	乔南辰	：	过奖了	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	阿姨 你放心我这就去	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	为什么不明天？越早越好啊	[unused41]
# word id 3 line = 10	乔逸晨哥们【吴梁】	：	等等，你知道她在什么地方吗？	[unused41]
# word id 1 line = 17	夏玖晞	：	嗯，是我自己愿意的	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	那我们也没办法了	[unused41]
#
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	我们也没说啥	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯对	[unused41]
#
#
# word id 2 line = 16	乔南辰	：	不用	[SEP]	就后天	[unused41]
#
# word id 1 line = 17	夏玖晞	：	……	[SEP]	大明星，你现在有多少粉丝？	[unused41]
# word id 0 line = 1	旁白	：	···	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	好	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	咳，我刚出道，哪里算大明星	[unused41]
# word id 0 line = 1	旁白	：	吃完饭后，大家都回去了	[SEP]	明天又是一场什么样的火花？	[unused41]
#
#
#
# word id 1 line = 16	乔南辰	：	你挺有自知自明	[unused41]
# word id 0 line = 8	班主任	：	同学们	[unused41]
#
# word id 2 line = 1	旁白	：	就这样聊着聊着已经快一点了，他们要起身回家了唐志承最终也答应一起办婚礼了。	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	必须	[SEP]	大嫂，我给你保证，三年后你回归我就已经是大明星	[unused41]
#
# word id 0 line = 9	李文君	：	老师好	[unused41]
#
#
# word id 2 line = 1	旁白	：	···	[unused41]
# word id 1 line = 17	夏玖晞	：	好啊，我等着	[unused41]
#
#
# word id 0 line = 10	黎沐雪[南辰妈妈]	：	老师好	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	我怎么不信呢	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	老师好	[unused41]
# word id 2 line = 1	旁白	：	他们来到点心区，看见有个女孩红着脸向他们跑来了	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	切，你看着吧	[unused41]
#
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	老师好	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	好，是你让我看的，你要是在三年以后没有成为大明星我第一个打死你	[unused41]
#
#
# word id 0 line = 11	【同学段甜忻	：	老师好	[unused41]
# word id 2 line = 19	苏诗梦	：	你脸好红哦	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	🙄	[SEP]	绝不会让你们失望的	[unused41]
#
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	老师好	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	我们很期待哦	[unused41]
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	老师好	[unused41]
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	没有……那有	[unused41]
#
# word id 1 line = 17	夏玖晞	：	那我们的孩子的干爹还是个明星呢	[unused41]
#
#
# word id 2 line = 16	乔南辰	：	乔沐雨，这是怎么回事？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	老师好	[unused41]
# word id 1 line = 16	乔南辰	：	说的也是	[unused41]
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	对对，如果我干儿子出世我一定要好好宠他	[unused41]
#
# word id 0 line = 12	【许雅婷】	：	老师好	[unused41]
#
# word id 2 line = 17	夏玖晞	：	沐雨，你怎么红成这样	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	那要是女的呢？	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	老师好	[unused41]
#
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	我……我……这个……咳嗯	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	都一样	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	老师好	[unused41]
#
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	就是呢	[SEP]	都一样	[SEP]	男女平等	[unused41]
# word id 2 line = 19	苏诗梦	：	你是谈恋爱了吗？	[unused41]
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	老师早	[unused41]
# word id 1 line = 16	乔南辰	：	管好你们自己的事就行，别打我孩子的注意	[unused41]
#
#
# word id 0 line = 15	宫宁	：	老师好	[unused41]
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	哈哈哈哈	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	我……	[unused41]
#
# word id 3 line = 8	神秘女子	：	阿姨对不起	[unused41]
#
# word id 3 line = 7	夏玖晞妈妈	：	孩子，你为什么和我说对不起	[unused41]
# word id 2 line = 17	夏玖晞	：	[恍然大悟]你和凌夜轩？……	[unused41]
#
# word id 3 line = 8	神秘女子	：	是我害了沫歌	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	你说什么	[unused41]
#
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	宫宁威胁李文君拿她家人要挟文君，所以文君只好照着宫宁的话去做了	[unused41]
#
# word id 3 line = 3	乔南辰	：	你……	[unused41]
#
# word id 3 line = 9	许雅婷	：	宫宁还让文君给沫歌下蒙汗药	[unused41]
#
# word id 3 line = 4	慕熠凤	：	你怎么知道的	[unused41]
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	嫂子，我要是说他给我表白了呢	[unused41]
#
# word id 3 line = 9	许雅婷	：	她在北齐找到了我向我说了所有的事实	[unused41]
#
#
# word id 3 line = 5	夏沫歌闺蜜【万琳】	：	然后呢，你下了吗？	[unused41]
# word id 2 line = 17	夏玖晞	：	真的假的	[unused41]
#
# word id 3 line = 8	神秘女子	：	我下了，但就放了一点	[SEP]	如果我去再晚一点沫歌就让宫宁……	[unused41]
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	闭嘴别说了	[SEP]	告诉我们沫歌在哪	[unused41]
#
#
# word id 2 line = 16	乔南辰	：	表白了？	[unused41]
# word id 3 line = 8	神秘女子	：	我不知道啊	[unused41]
#
# word id 3 line = 9	许雅婷	：	南城河……沫歌不会在南城河吧	[unused41]
#
# word id 3 line = 12	夏玖晞爸爸	：	什么？	[unused41]
#
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	嗯？	[SEP]	你想说什么	[unused41]
#
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	嗯嗯	[unused41]
# word id 3 line = 9	许雅婷	：	我认识沫歌早，我们两有事没事经常去哪里玩	[SEP]	有什么不快乐的事我们都会去哪里	[unused41]
#
# word id 3 line = 3	乔南辰	：	离这里远吗？	[unused41]
#
# word id 3 line = 9	许雅婷	：	不远二十公里左右	[unused41]
#
# word id 3 line = 3	乔南辰	：	叔叔阿姨，我先走一趟	[unused41]
#
# word id 1 line = 16	乔南辰	：	莫芸汐，你以后有工作吗？	[unused41]
#
#
# word id 3 line = 7	夏玖晞妈妈	：	小心啊	[unused41]
#
# word id 3 line = 10	乔逸晨哥们【吴梁】	：	等等我	[unused41]
#
# word id 2 line = 1	旁白	：	这时有个1.76的男子大步的走了过来	[unused41]
# word id 0 line = 16	乔南辰	：	老师好	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	没呢	[SEP]	怎么啦？	[unused41]
#
#
#
# word id 0 line = 17	夏玖晞	：	老师好	[unused41]
# word id 2 line = 21	凌夜轩	：	你们好	[unused41]
#
# word id 1 line = 16	乔南辰	：	来我公司做莫总吧	[unused41]
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	我们一起去吧	[unused41]
#
# word id 0 line = 8	班主任	：	嗯，都好	[SEP]	知道我为什么这么早叫醒大家吗？	[unused41]
# word id 2 line = 17	夏玖晞	：	嗯，你好	[unused41]
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	好啊	[unused41]
#
#
# word id 0 line = 9	李文君	：	为什么？	[unused41]
# word id 2 line = 16	乔南辰	：	给我解释一下	[unused41]
#
# word id 1 line = 16	乔南辰	：	我先上个厕所	[unused41]
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	毕业了	[unused41]
# word id 2 line = 21	凌夜轩	：	什么？	[unused41]
#
# word id 1 line = 17	夏玖晞	：	好	[SEP]	咳咳，琳琳，倩倩芸汐能帮个忙吗？	[unused41]
#
# word id 0 line = 8	班主任	：	对，你们毕业了	[SEP]	你们要离开这个学校了	[unused41]
#
# word id 2 line = 16	乔南辰	：	你跟我妹表白了？	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	说	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	舍不得鸭	[unused41]
#
#
# word id 2 line = 21	凌夜轩	：	对	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	说	[unused41]
#
#
# word id 0 line = 11	【同学段甜忻	：	是啊	[SEP]	舍不得	[SEP]	和大家在一起很开心，没想到终有离开的那一天	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	你说	[unused41]
#
# word id 2 line = 19	苏诗梦	：	说重点	[unused41]
#
# word id 0 line = 17	夏玖晞	：	段甜忻，你可以加我微信	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	这三年内帮我看好南辰	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	说重点	[unused41]
#
# word id 0 line = 11	【同学段甜忻	：	真的？	[unused41]
#
# word id 2 line = 17	夏玖晞	：	说重点	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	噗	[SEP]	大嫂，你是担心？	[unused41]
# word id 0 line = 17	夏玖晞	：	嗯	[unused41]
#
#
# word id 2 line = 21	凌夜轩	：	她愿意做我女朋友	[unused41]
#
# word id 1 line = 17	夏玖晞	：	呃	[SEP]	毕竟三年呢	[unused41]
#
# word id 0 line = 11	【同学段甜忻	：	谢谢	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	[看向乔沐雨]是真的吗？	[unused41]
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	你放心，我们一起看着他	[unused41]
# word id 0 line = 8	班主任	：	老师也舍不得你们	[SEP]	但是你们要相信，我们终究有相见的那一天	[unused41]
#
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	[看着莫芸汐]是，我同意做他女朋友	[unused41]
#
#
# word id 0 line = 10	黎沐雪[南辰妈妈]	：	嗯，老师	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	你放心	[unused41]
#
# word id 2 line = 17	夏玖晞	：	可是，夜轩，我们家沐雨还没毕业啊	[unused41]
#
#
# word id 0 line = 17	夏玖晞	：	老师，多年后我可以和逸晨回来看看吗？	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	不客气呢	[unused41]
#
#
# word id 2 line = 21	凌夜轩	：	我可以等	[unused41]
# word id 0 line = 8	班主任	：	当然可以	[SEP]	学校的大门永远欢迎你们	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	就是，这点小事交给我们	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	还有两年毕业，是两年	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	老师……	[unused41]
# word id 1 line = 17	夏玖晞	：	嗯嗯	[unused41]
#
#
#
# word id 2 line = 21	凌夜轩	：	我知道	[SEP]	我会等她的	[unused41]
# word id 0 line = 8	班主任	：	好了，你们多聊会下午四点多可以出发回家了	[unused41]
# word id 1 line = 1	旁白	：	乔南辰回来了	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	嗯老师	[unused41]
# word id 1 line = 16	乔南辰	：	你们吃饱了没？	[unused41]
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	真的吗？	[unused41]
#
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	逸晨	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	我先和我老婆回去了你们自己回去吧	[unused41]
# word id 2 line = 21	凌夜轩	：	嗯	[unused41]
# word id 0 line = 16	乔南辰	：	嗯？	[unused41]
#
#
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	我也要努力学习，早点毕业	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	哦	[unused41]
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	你该和沫歌说你的身份了吧？	[unused41]
# word id 2 line = 16	乔南辰	：	在学校给我专心点	[unused41]
#
#
#
# word id 0 line = 16	乔南辰	：	现在？	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	有了老婆亲兄弟都会忘了	[unused41]
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	嗯嗯	[unused41]
#
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	嗯，不然呢？回去说？太迟了	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	想当初咱们在一个学校，也不用担心什么	[unused41]
# word id 1 line = 16	乔南辰	：	当然	[unused41]
#
#
#
# word id 0 line = 16	乔南辰	：	我没有想好怎么说	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	你够狠	[unused41]
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	哼	[SEP]	你是来炫耀的嘛	[unused41]
#
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	怎么了？	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	牛逼了	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	没有没有	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	玖晞，咱们回去吧	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	咳	[SEP]	就是内个事……	[unused41]
#
#
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	是啊，该和沫歌说了	[SEP]	我们陪你	[unused41]
# word id 1 line = 17	夏玖晞	：	好	[SEP]	我们先回去了哦	[unused41]
# word id 2 line = 19	苏诗梦	：	你跟玖晞一个同学？	[unused41]
#
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	嗯陪你	[unused41]
#
#
# word id 3 line = 5	夏沫歌闺蜜【万琳】	：	好	[SEP]	叔叔阿姨，你们慢慢来	[unused41]
#
# word id 0 line = 16	乔南辰	：	行吧	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	是的	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	许雅婷带路	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	拜拜	[unused41]
#
#
# word id 3 line = 9	许雅婷	：	走吧	[unused41]
#
#
# word id 3 line = 1	旁白	：	···	[unused41]
#
# word id 1 line = 1	旁白	：	···	[unused41]
#
#
# word id 3 line = 1	旁白	：	做完亲子鉴定确定乔梓墨就是乔南辰的亲生骨肉后开心的回到了慕家	[unused41]
# word id 2 line = 17	夏玖晞	：	嘻嘻	[SEP]	很幸运遇到你们	[unused41]
# word id 0 line = 12	【许雅婷】	：	呜呜，大家要散了	[unused41]
#
# word id 3 line = 13	慕尘哓	：	怎么样？	[SEP]	墨墨？	[unused41]
#
# word id 3 line = 14	冷莫寒	：	是啊，玖晞南辰到底结果是什么	[unused41]
#
# word id 3 line = 15	夏玖晞	：	南辰，你说吧！	[unused41]
#
# word id 3 line = 3	乔南辰	：	嗯	[SEP]	乔梓墨是我儿子	[unused41]
#
#
#
# word id 0 line = 11	【同学段甜忻	：	没有关系	[SEP]	我们总有一天会见面的	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	我也是呢	[unused41]
#
# word id 1 line = 1	旁白	：	六分钟后乔南辰在微信群里说在他的私人别墅里集合因为有事要商议	[SEP]	果然乔南辰的一句话大家都来了私人别墅	[unused41]
#
# word id 0 line = 12	【许雅婷】	：	嗯啊	[unused41]
# word id 2 line = 21	凌夜轩	：	沐雨，我们去喝杯酒吧	[unused41]
# word id 3 line = 13	慕尘哓	：	真的啊？	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	怎么了？叫我们什么事	[unused41]
#
# word id 0 line = 16	乔南辰	：	咳，万琳	[unused41]
#
# word id 2 line = 20	乔沐雨[南辰妹妹]	：	好	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	什么事啊	[unused41]
#
#
#
#
# word id 2 line = 16	乔南辰	：	你们少喝点	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	学长你叫我？	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	玖晞呢？	[unused41]
#
#
# word id 2 line = 21	凌夜轩	：	你放心吧	[unused41]
# word id 0 line = 16	乔南辰	：	出来一下	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	是啊，怎么不见大嫂	[unused41]
#
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	哦好	[unused41]
# word id 2 line = 16	乔南辰	：	就因为你，我才不放心	[unused41]
# word id 3 line = 14	冷莫寒	：	就说嘛，我们家玖晞怎么会……	[unused41]
# word id 1 line = 18	乔梓墨	：	妈咪走了。	[unused41]
#
#
#
# word id 0 line = 1	旁白	：	乔逸晨和万琳走出了教室	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	咳咳	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	老父亲的心情，你得理解一下凌兄	[unused41]
#
#
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	什么意思？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	你们怎么在外面不和他们说话？	[unused41]
# word id 2 line = 21	凌夜轩	：	了解	[unused41]
#
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	万琳问你个问题，你能如实回答吗？	[unused41]
# word id 2 line = 16	乔南辰	：	唐志承，你到底是谁的兄弟	[unused41]
# word id 1 line = 18	乔梓墨	：	妈咪出去见她的男同学顾梓铭了	[SEP]	然后我爸比吃醋了	[unused41]
#
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	你说	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	噗	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	你的你的	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	让大家担心了	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	噗	[unused41]
#
# word id 0 line = 16	乔南辰	：	关于沫歌的	[unused41]
#
#
# word id 2 line = 17	夏玖晞	：	😂😂	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	然后呢	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	沫…沫歌？她怎么了？	[unused41]
#
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	如果有机会，我想再次回母校怀念以前	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	没事，别紧张	[SEP]	如果我们欺骗了，你们你们会怎么办啊？	[unused41]
# word id 1 line = 16	乔南辰	：	我叫你们是想帮我想个办法试探一下玖晞的反应	[unused41]
#
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	我们总有一天会去咱们母校的	[unused41]
# word id 3 line = 4	慕熠凤	：	没事	[SEP]	南辰，既然你这么快的当了爸爸，你现在是总裁工作难免会多一些但是我还想给你说句，抽个时间陪陪你孩子还有你妻子	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	[疑问]欺骗？你们骗我们什么了？	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	我懂了	[SEP]	想要试探玖晞的第一反应？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯，但愿	[unused41]
#
# word id 0 line = 16	乔南辰	：	我……不知道怎么说	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	是的	[SEP]	弄个假象就OK	[unused41]
#
# word id 3 line = 3	乔南辰	：	我明白舅舅	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	这事你和沫歌说吧！	[unused41]
# word id 2 line = 17	夏玖晞	：	好了，不要这么伤感	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	不过……乔大总裁这不是你的风格	[unused41]
#
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	没错，这不是乔南辰的注意	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	是啊，也不知道我们的宿舍变了没有	[unused41]
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	什么？	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	为什么让我去	[unused41]
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	玖晞明天去公司吗？	[unused41]
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	你去把沫歌叫出来呗	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯哼，也不知道我们的宿舍变了没有	[unused41]
#
#
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	你是她闺蜜	[unused41]
# word id 2 line = 16	乔南辰	：	抽个时间回去看看不久好了	[unused41]
#
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	什么？	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	咳，你说的哦	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	算你狠	[SEP]	咳，沫歌可是讨厌别人欺骗，如果事情很严重……嘿嘿	[unused41]
#
# word id 3 line = 3	乔南辰	：	才回来没多久，过几天吧	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	什么？	[unused41]
#
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	我求你了别耽误时间了行吗？	[unused41]
# word id 2 line = 16	乔南辰	：	嗯	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	那是谁的注意，鹿迪你出的？	[unused41]
#
#
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	不是	[unused41]
# word id 2 line = 17	夏玖晞	：	南辰，你和唐志承聊吧！我和芸汐还有诗梦去那边看看	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	行	[unused41]
#
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	芸汐？	[unused41]
# word id 2 line = 16	乔南辰	：	好	[unused41]
# word id 0 line = 1	旁白	：	万琳又回到了教室里	[unused41]
#
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	也不是我	[unused41]
#
# word id 0 line = 17	夏玖晞	：	万琳，你出去做什么	[unused41]
# word id 2 line = 19	苏诗梦	：	嗯。。。	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	不会是墨墨吧？	[unused41]
#
# word id 3 line = 15	夏玖晞	：	没事，我可以明天去	[unused41]
#
# word id 3 line = 16	乔逸晨哥们【鹿迪】	：	别太累了。多少休息会儿	[unused41]
#
# word id 3 line = 15	夏玖晞	：	真的没事	[unused41]
#
# word id 3 line = 3	乔南辰	：	那行吧	[SEP]	明天就工作	[unused41]
#
# word id 3 line = 17	慕晴幻	：	别才拼了	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	你跟我出去一下	[unused41]
#
#
#
# word id 3 line = 15	夏玖晞	：	嗯，放心	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	对，就是墨墨	[unused41]
# word id 0 line = 17	夏玖晞	：	什么事？	[unused41]
#
#
# word id 3 line = 1	旁白	：	林倩倩拉着乔梓墨进来了	[unused41]
#
#
#
# word id 2 line = 1	旁白	：	···	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	靠	[SEP]	我不信	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	玖晞，结果怎么样？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	先和我来吧！你家男朋友找你有事	[unused41]
#
#
#
# word id 3 line = 5	夏沫歌闺蜜【万琳】	：	他们关系百分之99	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	说实话我一开始也不信这是墨墨说的	[unused41]
#
# word id 2 line = 1	旁白	：	刚出生的婴儿躺在婴儿车睡得特别香	[unused41]
#
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	太好了	[unused41]
#
#
#
# word id 3 line = 15	夏玖晞	：	你们在玩什么？	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	这孩子长大了不得了	[unused41]
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	谢谢护士	[unused41]
#
#
#
# word id 0 line = 17	夏玖晞	：	好吧！同学们我出去一下哈	[unused41]
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	积木啊	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	确实	[SEP]	不像三岁的孩子	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	干嘛去？	[unused41]
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	😂	[unused41]
#
#
# word id 1 line = 18	乔梓墨	：	我虽3岁但请不要小看我们小孩子	[unused41]
# word id 3 line = 18	乔梓墨	：	妈妈，你刚才去哪里了？	[unused41]
# word id 2 line = 22	护士	：	不客气。	[unused41]
#
#
#
# word id 0 line = 17	夏玖晞	：	我不知道？	[unused41]
# word id 3 line = 15	夏玖晞	：	我和爸爸去外面办了点事情	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	哈哈哈 不会不会	[SEP]	墨墨，你倒是说说看要我们怎么帮你爹地造假象？	[unused41]
#
#
#
# word id 3 line = 18	乔梓墨	：	哦哦	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	呃万琳你叫沫歌什么事	[unused41]
# word id 1 line = 18	乔梓墨	：	中毒 车祸 发生 昏迷 绝症 装死六选一你们挑一个	[unused41]
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	小家伙长大后绝对又是个小美人	[unused41]
#
# word id 3 line = 19	慕尘峰[姥爷]	：	如果你们去工作孩子呢？	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	学长叫的不管我事一起出去吧好不好	[unused41]
#
# word id 3 line = 15	夏玖晞	：	外公说的对啊！我都没想过	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	……	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	眼睛好像芸汐	[unused41]
# word id 3 line = 3	乔南辰	：	不如送到妈那里吧	[unused41]
#
#
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	……	[unused41]
# word id 3 line = 15	夏玖晞	：	会不会辛苦妈妈了	[unused41]
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	乔逸晨，我给你说一会儿他们出来了你说	[unused41]
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	是啊	[SEP]	鼻子 眉毛像鹿迪呢	[unused41]
#
# word id 3 line = 3	乔南辰	：	没事，反正还有我妹呢	[unused41]
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	同意	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	……	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	几个小时前，我和芸汐还在家给孩子起小名，如果是男孩叫布丁女孩叫开心	[unused41]
#
#
# word id 3 line = 15	夏玖晞	：	噗	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	好吧，我跟你们出去就是了	[SEP]	沫歌走	[unused41]
# word id 3 line = 18	乔梓墨	：	爸比，我可以不去奶奶家吗？	[unused41]
# word id 2 line = 16	乔南辰	：	不错	[unused41]
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	……	[unused41]
# word id 3 line = 3	乔南辰	：	为什么？	[unused41]
# word id 0 line = 17	夏玖晞	：	嗯	[unused41]
#
#
#
# word id 3 line = 18	乔梓墨	：	不喜欢我的人，我为什么要讨那个厌呢？我要去相信我妈咪的人家里	[unused41]
#
# word id 0 line = 1	旁白	：	沫歌出来了……	[unused41]
# word id 2 line = 17	夏玖晞	：	小开心，你好啊！我是你干妈妈	[unused41]
#
#
# word id 3 line = 15	夏玖晞	：	墨墨，奶奶没有不喜欢你，她只是很意外，我们三年后才回国而且妈妈也没有告诉过任何人你的存在。	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	……	[unused41]
#
#
# word id 2 line = 18	乔梓墨	：	妈咪，我出生的时候也是这样的吗？	[unused41]
# word id 3 line = 18	乔梓墨	：	那为什么舅舅他们相信你，喜欢我呢？	[unused41]
#
#
#
# word id 2 line = 17	夏玖晞	：	当然啦	[SEP]	每个宝宝们出生都会这样子	[SEP]	但你出生的时候是睁着眼睛的	[unused41]
# word id 3 line = 15	夏玖晞	：	[看向乔南辰]南辰……	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	咳，他们出来了	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	……	[unused41]
#
#
#
# word id 3 line = 3	乔南辰	：	咳懂	[unused41]
#
#
# word id 2 line = 18	乔梓墨	：	哦哦	[SEP]	妈咪，我们把妹妹抱起来合个影怎么样？	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	……	[SEP]	墨墨	[SEP]	你真是乔南辰的儿子	[unused41]
# word id 3 line = 15	夏玖晞	：	嗯	[unused41]
#
# word id 2 line = 18	乔梓墨	：	干爹，好不好？	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	曹	[unused41]
#
# word id 2 line = 17	夏玖晞	：	问你干爸	[unused41]
# word id 0 line = 16	乔南辰	：	眼没瞎	[unused41]
#
#
#
# word id 1 line = 16	乔南辰	：	过奖了	[unused41]
#
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	但，我不会抱啊	[unused41]
# word id 0 line = 17	夏玖晞	：	你们在这里做什么	[unused41]
#
# word id 1 line = 18	乔梓墨	：	选一个吧	[unused41]
#
# word id 2 line = 16	乔南辰	：	你学啊	[SEP]	老婆，你来教他	[unused41]
#
# word id 3 line = 3	乔南辰	：	墨墨	[unused41]
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	别问我，问你男朋友	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	当然是越狠越好	[unused41]
# word id 2 line = 17	夏玖晞	：	我给你示范一下好了	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	鹿迪什么事啊？	[unused41]
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	那你的意思？	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	嗯	[SEP]	那不如，你抱着孩子吧	[unused41]
#
# word id 3 line = 18	乔梓墨	：	[看向乔南辰]嗯？	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	问乔逸晨	[unused41]
#
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	绝症咋样？	[unused41]
#
#
# word id 2 line = 17	夏玖晞	：	[看向乔南辰]老公，要不你抱吧！	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	噗	[SEP]	你想咒乔南辰啊？	[unused41]
# word id 0 line = 17	夏玖晞	：	逸晨？	[unused41]
#
#
#
#
# word id 2 line = 16	乔南辰	：	我？	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	额	[unused41]
#
# word id 0 line = 16	乔南辰	：	咳咳，我…不是一个普通的家庭，我的家庭很富有所以我一直在骗你们	[unused41]
#
# word id 3 line = 3	乔南辰	：	奶奶她很喜欢你的，你妈妈说的是她就是很意外，毕竟三年了突然冒出个你自然多想了。慢慢的就会接受你的	[unused41]
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	咳，我觉得也是 乔总不如你抱吧	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	那不如……车祸？	[unused41]
#
#
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	乔逸晨是海城风都云公司董事长儿子……	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	呃呃呃	[unused41]
# word id 2 line = 16	乔南辰	：	这个……	[unused41]
#
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	等一下	[SEP]	你说乔逸晨是……风都云董事长的儿子？	[unused41]
# word id 1 line = 18	乔梓墨	：	行啦！就车祸昏迷得了	[unused41]
# word id 2 line = 18	乔梓墨	：	爹地快点抱啊	[unused41]
#
#
# word id 3 line = 18	乔梓墨	：	爸比，你是谁生的？	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	这个好	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	对	[unused41]
#
# word id 2 line = 16	乔南辰	：	那行吧	[SEP]	这么轻啊	[unused41]
#
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	这个确实好	[unused41]
#
#
# word id 0 line = 17	夏玖晞	：	[惊呆]逸晨这是真的吗？	[unused41]
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	鬼点子挺多	[unused41]
# word id 2 line = 17	夏玖晞	：	是的，孩子刚出生生命很脆弱的	[unused41]
#
#
# word id 3 line = 3	乔南辰	：	怎么问这个？	[unused41]
# word id 0 line = 16	乔南辰	：	是，鹿迪说的没有错	[unused41]
#
# word id 1 line = 16	乔南辰	：	就车祸昏迷吧	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	小宝贝，叫爸爸啊	[unused41]
#
# word id 0 line = 17	夏玖晞	：	你为什么才和我说？	[unused41]
#
# word id 1 line = 18	乔梓墨	：	嗯嗯	[unused41]
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	[笑]鹿迪，你是不是傻？她还小况且刚出事哪里听的懂	[unused41]
#
# word id 1 line = 16	乔南辰	：	吴梁你是明星，你等下去新天地找玖晞就说我出车祸了	[SEP]	鹿迪，你去医院告诉所有医生让他们配合	[SEP]	留下一个医生就行	[unused41]
# word id 0 line = 16	乔南辰	：	我……不知道为什么才说	[unused41]
#
# word id 3 line = 18	乔梓墨	：	我就问问	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	我不要你觉得 我要我觉得	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	好的	[unused41]
# word id 0 line = 17	夏玖晞	：	没事	[unused41]
#
#
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	你牛	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	请问玖晞问你是怎么车祸的我们怎么说？	[unused41]
# word id 3 line = 3	乔南辰	：	你奶奶生的	[unused41]
#
# word id 3 line = 18	乔梓墨	：	对啊！你是奶奶生的当然帮她了，我是我妈咪生的自然要帮我妈咪说话	[unused41]
#
# word id 3 line = 3	乔南辰	：	……	[unused41]
#
#
# word id 1 line = 16	乔南辰	：	就说我带着墨墨出去玩了不小心撞车了	[SEP]	墨墨是皮外伤	[unused41]
# word id 3 line = 4	慕熠凤	：	……	[unused41]
#
#
# word id 3 line = 14	冷莫寒	：	……	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	好事，好事	[unused41]
# word id 2 line = 17	夏玖晞	：	好了好了	[SEP]	还拍照吗？	[unused41]
# word id 3 line = 15	夏玖晞	：	……	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	无奈了	[unused41]
#
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	……	[unused41]
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	秒懂	[SEP]	什么时候开始？	[unused41]
# word id 0 line = 17	夏玖晞	：	倩倩你在说什么哦	[unused41]
# word id 3 line = 20	乔逸晨哥们【唐志承】	：	……	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	你可记的你小时候和我在风都云公司玩的的时候撞了一个男孩	[unused41]
#
# word id 3 line = 17	慕晴幻	：	……	[unused41]
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	拍	[unused41]
# word id 0 line = 17	夏玖晞	：	想起来了	[unused41]
# word id 3 line = 13	慕尘哓	：	……	[unused41]
#
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯	[unused41]
# word id 3 line = 19	慕尘峰[姥爷]	：	……	[unused41]
#
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	你们在说的什么？听不懂	[unused41]
# word id 3 line = 1	旁白	：	众人惊呆了，怎么也想不到小小的年纪能说出这样的话	[unused41]
# word id 1 line = 18	乔梓墨	：	就今天吧	[SEP]	越早越好	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	哪就快点吧	[unused41]
# word id 3 line = 17	慕晴幻	：	咳咳，小小的年纪知道护自己妈妈了	[unused41]
#
#
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	墨墨说的是	[unused41]
# word id 3 line = 21	慕黎诚	：	玖晞，这孩子说出的话也这么的惊人	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	听不懂别听	[unused41]
# word id 3 line = 15	夏玖晞	：	咳，过奖了哈！别介意	[SEP]	墨墨，我们回去吧	[unused41]
# word id 1 line = 16	乔南辰	：	嗯嗯，志承你跟我去医院还有墨墨	[unused41]
# word id 2 line = 1	旁白	：	不一会儿床上的莫芸汐醒了。	[unused41]
#
#
# word id 3 line = 18	乔梓墨	：	回哪去	[unused41]
#
#
#
# word id 1 line = 18	乔梓墨	：	嗯	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	咳咳	[SEP]	就这事啊	[SEP]	未来的总经理，我家沫歌靠你养了啊	[unused41]
# word id 3 line = 3	乔南辰	：	我们的家	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	老公	[unused41]
#
#
#
# word id 3 line = 18	乔梓墨	：	哦	[unused41]
#
# word id 0 line = 17	夏玖晞	：	我不需要靠他，我自己能养活我自己	[unused41]
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	醒了？别动好好躺着	[unused41]
# word id 3 line = 21	慕黎诚	：	那明天？	[unused41]
#
# word id 1 line = 13	乔逸晨哥们【吴梁】	：	一会儿我给你们弄点伤口道具	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	就是呢	[unused41]
#
# word id 3 line = 15	夏玖晞	：	再说吧	[unused41]
#
#
#
# word id 3 line = 21	慕黎诚	：	嗯	[unused41]
# word id 1 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯！	[unused41]
# word id 0 line = 17	夏玖晞	：	你放心我不会怪你的。	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯，孩子呢	[unused41]
# word id 3 line = 22	慕炫昊	：	墨墨，别再自己跑出来了好吗？以后要记得和家长说一下再出来	[unused41]
#
#
# word id 3 line = 18	乔梓墨	：	知道了，二表舅	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	就怕玖晞知道会砍死我们	[unused41]
#
#
#
# word id 3 line = 22	慕炫昊	：	嗯！	[unused41]
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	不会的	[unused41]
# word id 3 line = 13	慕尘哓	：	以后有事打我们电话不能擅自离开家	[unused41]
#
# word id 2 line = 17	夏玖晞	：	我怀里呢	[unused41]
#
# word id 3 line = 18	乔梓墨	：	好	[unused41]
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	但愿	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	玖晞，你抱近点	[unused41]
# word id 3 line = 3	乔南辰	：	我们该走了	[unused41]
# word id 1 line = 1	旁白	：	···	[unused41]
#
#
# word id 3 line = 6	夏沫歌闺蜜【林倩倩】	：	墨墨我们先出去等着吧	[unused41]
# word id 1 line = 1	旁白	：	半个小时候乔南辰和夏玖晞来到了，咖啡馆	[unused41]
#
#
# word id 3 line = 11	夏沫歌闺蜜【莫芸汐】	：	咳，一起	[unused41]
# word id 0 line = 16	乔南辰	：	真的？	[unused41]
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	老大，你们才来啊	[unused41]
#
# word id 3 line = 5	夏沫歌闺蜜【万琳】	：	嗯嗯	[unused41]
#
# word id 0 line = 17	夏玖晞	：	嗯	[unused41]
# word id 2 line = 17	夏玖晞	：	好	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	对了，你们回老家还是？	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	孩子的大名你们想好了没？	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	还没呢	[unused41]
# word id 0 line = 17	夏玖晞	：	我想回海城好久没见我家人了	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	唐志承，不如你给孩子起？	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	大嫂，你是海城的？	[unused41]
#
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	可别，人家都是自己亲爹起，我干嘛要起	[SEP]	不要	[unused41]
# word id 0 line = 17	夏玖晞	：	是的	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	哈哈	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	我们也是	[unused41]
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	鹿迪，你给起个名字？	[unused41]
# word id 0 line = 17	夏玖晞	：	[偷笑]哦是吗？	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	我想想	[unused41]
# word id 0 line = 16	乔南辰	：	嗯	[unused41]
#
#
# word id 2 line = 17	夏玖晞	：	芸汐，你现在不能乱动知道吗？	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	那我们做一个车好不好？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯嗯	[unused41]
#
# word id 0 line = 16	乔南辰	：	好，大家回去收拾一下行李吧	[unused41]
#
#
#
# word id 2 line = 17	夏玖晞	：	来吧，喂孩子母乳	[unused41]
# word id 0 line = 17	夏玖晞	：	嗯	[unused41]
# word id 1 line = 16	乔南辰	：	堵车	[SEP]	什么事？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	呃……那个老公你们先出去行吗？	[unused41]
#
#
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	我要和万琳办婚礼了	[unused41]
# word id 3 line = 16	乔逸晨哥们【鹿迪】	：	呃	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	好事啊	[unused41]
# word id 3 line = 20	乔逸晨哥们【唐志承】	：	嗯哼	[unused41]
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	南辰，玖晞	[SEP]	我想让芸汐和我们一起办	[unused41]
# word id 3 line = 3	乔南辰	：	外公外婆，舅舅舅妈，表哥表姐我们走了	[unused41]
# word id 0 line = 1	旁白	：	···	[unused41]
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	我是你老公，我不出去。其他人出去吧	[unused41]
# word id 3 line = 19	慕尘峰[姥爷]	：	好	[unused41]
# word id 1 line = 16	乔南辰	：	唐志承，你是什么意见？	[unused41]
#
#
#
#
# word id 3 line = 4	慕熠凤	：	嗯，注意安全	[unused41]
# word id 1 line = 17	夏玖晞	：	人多多好啊，热闹	[unused41]
#
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	不行不行，有玖晞就可以了。	[SEP]	你们都出去	[unused41]
# word id 3 line = 15	夏玖晞	：	嗯	[SEP]	拜拜	[unused41]
# word id 0 line = 1	旁白	：	门外	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	我就要和我闺蜜一起办，反正你看办	[SEP]	不然，咱俩别结婚了	[unused41]
#
#
#
#
# word id 3 line = 22	慕炫昊	：	嗯	[unused41]
# word id 2 line = 16	乔南辰	：	鹿迪，你老婆现在可不能激动，咱们还是出去吧	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	万琳	[SEP]	不是我……	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我天……	[SEP]	这……	[unused41]
# word id 3 line = 1	旁白	：	终于找到了墨墨，把墨墨接回去了	[unused41]
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	你什么你	[SEP]	人家莫芸汐和鹿迪同意为什么你不同意	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	行吧	[unused41]
#
#
#
# word id 3 line = 1	旁白	：	···	[unused41]
# word id 1 line = 16	乔南辰	：	够了	[SEP]	我和我老婆来不是听你吵架的	[unused41]
# word id 2 line = 17	夏玖晞	：	墨墨，你也跟你爸爸出去吧	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	哈哈	[unused41]
#
# word id 1 line = 17	夏玖晞	：	唐志承，其实我觉得一起办挺好啊！	[unused41]
# word id 3 line = 1	旁白	：	慕黎城跟着他爸爸很快走进了医院，来到了病房门口	[unused41]
# word id 2 line = 18	乔梓墨	：	哦	[unused41]
#
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	如果我们和鹿迪一起的话，那吴梁也加进来吗？	[unused41]
# word id 3 line = 12	夏玖晞爸爸	：	哥	[unused41]
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	……	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	我都看不下去了	[unused41]
#
# word id 3 line = 22	慕炫昊	：	爸	[unused41]
#
# word id 1 line = 16	乔南辰	：	不是，唐志承你怎么越说越离谱	[unused41]
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	墨墨，走	[unused41]
#
# word id 3 line = 13	慕尘哓	：	爸	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	你放心吧！倩倩不会和你们一起结婚	[SEP]	人家有自己的决定	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	老天爷始终不舍把这两人拆开	[unused41]
# word id 2 line = 18	乔梓墨	：	嗯嗯	[unused41]
#
# word id 3 line = 17	慕晴幻	：	爸爸	[unused41]
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	再说了，和鹿迪芸汐一起办婚礼你会死啊？	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	玖晞怎么样了？	[unused41]
#
# word id 2 line = 1	旁白	：	···	[unused41]
#
# word id 1 line = 17	夏玖晞	：	万琳，好好说话	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	是啊	[SEP]	多好	[unused41]
#
# word id 3 line = 12	夏玖晞爸爸	：	现在醒了，又睡着了	[unused41]
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	懒得理他	[unused41]
#
#
#
# word id 2 line = 1	旁白	：	医院 VIP病房	[unused41]
# word id 3 line = 4	慕熠凤	：	你们在门外，谁在里面照看玖晞？	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	你们看，乔南辰在的时候玖晞睡的很香	[unused41]
#
# word id 1 line = 16	乔南辰	：	一会鹿迪和莫芸汐来了，听听他们的意见	[unused41]
# word id 3 line = 7	夏玖晞妈妈	：	哥，南辰在里面呢	[unused41]
#
#
# word id 1 line = 17	夏玖晞	：	你什么时候叫的	[unused41]
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	自己男朋友陪着当然睡的香	[unused41]
#
# word id 3 line = 4	慕熠凤	：	嗯	[unused41]
#
# word id 2 line = 16	乔南辰	：	鹿迪，该给你女儿起名字了	[unused41]
# word id 1 line = 16	乔南辰	：	微信	[unused41]
#
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	是啊	[unused41]
# word id 1 line = 17	夏玖晞	：	。。你神速度啊	[unused41]
#
# word id 3 line = 17	慕晴幻	：	爸，你是不是都知道了？	[unused41]
#
#
#
# word id 3 line = 4	慕熠凤	：	不然呢？	[SEP]	你们为什么不早点告诉我	[SEP]	养你们何用？	[unused41]
# word id 1 line = 16	乔南辰	：	夫人，你夸奖了	[unused41]
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	我想想	[SEP]	就叫……鹿妍熙吧	[unused41]
#
#
# word id 3 line = 13	慕尘哓	：	爸我们……	[unused41]
#
# word id 1 line = 1	旁白	：	不久后鹿迪牵着莫芸汐来了	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	妍熙？嗯，这个名字好	[unused41]
#
# word id 3 line = 12	夏玖晞爸爸	：	是我不让他们说的	[SEP]	别怪孩子们	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯……	[unused41]
# word id 1 line = 17	夏玖晞	：	芸汐	[unused41]
#
#
#
#
# word id 3 line = 4	慕熠凤	：	算了，我进去看看	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	玖晞	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	芸汐	[unused41]
#
#
# word id 2 line = 17	夏玖晞	：	那我们就叫鹿妍熙	[unused41]
#
# word id 1 line = 16	乔南辰	：	你们来了？	[SEP]	坐吧	[unused41]
# word id 3 line = 1	旁白	：	慕熠凤小心翼翼的进了病房生怕会吵醒玖晞，然而她已经醒了	[unused41]
#
#
#
# word id 3 line = 15	夏玖晞	：	[惊呆了]舅舅，你怎么在这？	[SEP]	你不是在北齐吗？	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	嗯嗯	[SEP]	你发微信是什么意思？	[SEP]	有什么事啊？	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	嗯？	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	是挺好听的	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	我爱你	[unused41]
#
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	[脸红]我也爱你	[unused41]
# word id 2 line = 18	乔梓墨	：	妈咪，你肚子里的弟弟或者妹妹什么时候才能出来呢？	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	[惊呆]你俩秀恩爱去一边秀谢谢	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	就是	[unused41]
# word id 2 line = 17	夏玖晞	：	还有好几个月呢	[unused41]
#
#
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	宝贝晚上，约会吗？	[unused41]
#
# word id 2 line = 18	乔梓墨	：	哦	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	阔以，亲爱的	[unused41]
#
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	够了	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	墨墨，你现在有这个妹妹陪你玩不好吗？	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	真是过分了	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	哈哈哈哈哈	[unused41]
# word id 2 line = 18	乔梓墨	：	好啊，只是她太小了	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	她长大了会陪你玩的	[unused41]
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	莫芸汐💔	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	💔	[unused41]
#
#
# word id 2 line = 18	乔梓墨	：	嗯嗯	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	至于吗你们	[unused41]
#
# word id 1 line = 17	夏玖晞	：	鹿迪，你和芸汐同意和万琳唐志承一起办婚礼吗？	[unused41]
#
# word id 2 line = 16	乔南辰	：	玖晞，咱们回家吧！	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	就是啊	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	不管	[unused41]
# word id 2 line = 17	夏玖晞	：	好	[unused41]
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	😓	[unused41]
#
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	为什么不呢？这样热闹	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	唐志承	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	多待会呗	[unused41]
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	你……	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	怎么了？	[unused41]
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	不了，在医院待的时间久了对孩子还有我老婆身体不好	[unused41]
#
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	你不是和吴梁在一起吗？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	啧啧	[unused41]
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	是啊，热闹	[SEP]	我们还想让墨墨当花童呢	[unused41]
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	呃……出了点事	[unused41]
#
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	那你们开车慢点	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	什么呀	[unused41]
#
#
# word id 2 line = 16	乔南辰	：	嗯	[unused41]
# word id 0 line = 14	乔逸晨哥们【鹿迪】	：	说啊	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	芸汐，唐志承不同意咱们一起办	[unused41]
#
#
#
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	快说	[unused41]
# word id 2 line = 17	夏玖晞	：	墨墨，咱们回去吧！	[unused41]
#
#
# word id 0 line = 3	乔逸晨哥们【唐志承】	：	吴梁在和宫宁说话	[unused41]
# word id 3 line = 3	乔南辰	：	舅舅	[unused41]
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	为什么？	[unused41]
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	谁知道	[unused41]
# word id 3 line = 4	慕熠凤	：	我是在北齐，我在北齐难道就不知道你们的情况了吗？	[unused41]
#
#
# word id 2 line = 18	乔梓墨	：	好	[SEP]	干妈干爹拜拜	[unused41]
# word id 3 line = 15	夏玖晞	：	舅舅我……	[unused41]
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	唐志承，你啥意思？怕我们吃你的饭喝你的水还是什么？	[unused41]
#
#
#
# word id 2 line = 14	乔逸晨哥们【鹿迪】	：	拜拜	[unused41]
# word id 3 line = 4	慕熠凤	：	你别说话	[SEP]	[看向乔南辰]你告诉我，宋羽洛是什么人？哪家的女儿？	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	我……要是两人一起办得花多少钱	[unused41]
#
#
#
# word id 3 line = 3	乔南辰	：	舅舅，她曾经是我初中同学，她在初中对我有好感，我是对她没有的	[SEP]	昨天 我们刚见面	[unused41]
#
# word id 1 line = 14	乔逸晨哥们【鹿迪】	：	你缺钱吗？你不缺吧？	[SEP]	你放心，一起办但是你一半钱我们一半钱这样OK吗？	[unused41]
# word id 3 line = 4	慕熠凤	：	所以呢？你让人家算计了？	[unused41]
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	拜拜	[unused41]
#
#
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	我考虑一下	[unused41]
# word id 3 line = 3	乔南辰	：	呃……我也是一时大意了	[unused41]
#
#
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	算了算了	[SEP]	我不结婚了，我回头找个更好的男朋友和我结婚	[unused41]
#
# word id 3 line = 4	慕熠凤	：	宋羽洛他爹是谁？	[unused41]
#
# word id 2 line = 3	乔逸晨哥们【唐志承】	：	拜拜	[unused41]
#
# word id 1 line = 4	夏沫歌闺蜜【莫芸汐】	：	[惊讶]万琳，你这是？	[unused41]
# word id 3 line = 3	乔南辰	：	不知道我对她家不感兴趣	[unused41]
#
#
#
# word id 3 line = 21	慕黎诚	：	爸，宋羽洛爸爸是Y市宋氏集团董事长叫宋明辉	[unused41]
# word id 1 line = 6	夏沫歌闺蜜【万琳】	：	没错我不结婚了	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	Y市？	[SEP]	你怎么知道	[unused41]
# word id 1 line = 3	乔逸晨哥们【唐志承】	：	不行	[unused41]
#
# word id 2 line = 6	夏沫歌闺蜜【万琳】	：	拜拜	[unused41]
#
# word id 3 line = 13	慕尘哓	：	我们和我哥查的	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	很好	[SEP]	玖晞，你现在怎么样？	[unused41]
# word id 2 line = 17	夏玖晞	：	芸汐有什么事，打电话给我	[unused41]
#
#
# word id 3 line = 15	夏玖晞	：	舅舅我挺好	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	这点小事不足够让你住院，你到底怎么回事？	[unused41]
# word id 0 line = 4	夏沫歌闺蜜【莫芸汐】	：	什么？	[SEP]	宫宁	[SEP]	他还敢来	[SEP]	不行我要出去	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	好，我知道了	[unused41]
#
#
# word id 3 line = 1	旁白	：	这时大家才知道原来慕熠凤并不知道玖晞中毒的事情，这时慕熠凤觉得不对	[unused41]
# word id 2 line = 1	旁白	：	···	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	你们在瞒我什么？	[SEP]	[看向夏皓文]皓文，你告诉我	[unused41]
#
# word id 2 line = 1	旁白	：	多天后……夏玖晞的肚子一天比一天大了，她现在已经九个月了，每天在家待着期待着肚子里的宝宝们长什么样子	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	我也去	[unused41]
# word id 3 line = 12	夏玖晞爸爸	：	哥……	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	你怎么下来了	[unused41]
# word id 3 line = 4	慕熠凤	：	怎么？	[unused41]
#
#
# word id 3 line = 12	夏玖晞爸爸	：	玖晞中毒了……	[unused41]
# word id 2 line = 17	夏玖晞	：	我就是想喝水	[unused41]
#
# word id 3 line = 4	慕熠凤	：	什么？你说什么？	[SEP]	中毒？	[SEP]	怎么会……	[unused41]
# word id 0 line = 6	夏沫歌闺蜜【万琳】	：	我也去	[SEP]	唐志承你在这里看着吧	[SEP]	我们出去	[unused41]
#
#
# word id 3 line = 13	慕尘哓	：	是宋羽洛约玖晞出去的吃了她点的东西就……就中毒了，那食物里含有巴豆成分	[unused41]
#
# word id 2 line = 16	乔南辰	：	喝水给我说，谁让你下来的	[unused41]
#
#
# word id 0 line = 1	旁白	：	···	[unused41]
# word id 3 line = 4	慕熠凤	：	巴豆？	[unused41]
# word id 2 line = 17	夏玖晞	：	哎呀，没事我怀墨墨的倒水就是我一个人到的也没出啥事	[unused41]
#
#
#
# word id 3 line = 13	慕尘哓	：	对	[unused41]
#
# word id 0 line = 1	旁白	：	内个乔南辰外公去世的内容我就不写了，就直接过去了哈！	[SEP]	新的一天	[SEP]	上午9:00	[unused41]
# word id 2 line = 16	乔南辰	：	那是在美国，你一个人现在不行	[unused41]
# word id 3 line = 1	旁白	：	慕尘哓拿出监控视频给自家老爸看，脸色更愤怒了	[unused41]
#
#
#
# word id 2 line = 17	夏玖晞	：	哎	[SEP]	对了，你把倩倩琳琳他们叫来了吗？说好的今天要吃个饭	[unused41]
# word id 3 line = 4	慕熠凤	：	宋明辉的女儿？	[SEP]	真是了不起	[SEP]	尘哓，随我去Y市	[unused41]
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	吴梁，你叫我出来做什么？	[unused41]
#
#
#
# word id 2 line = 16	乔南辰	：	嗯，我已经通知了，今天啊在家吃饭	[unused41]
# word id 3 line = 22	慕炫昊	：	爸，我和我大哥一起	[unused41]
#
#
# word id 3 line = 17	慕晴幻	：	我也想去	[unused41]
# word id 2 line = 17	夏玖晞	：	行，听你的	[SEP]	老公，你觉得肚子里是两个男孩还是两个女孩？	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	我有事要宣布	[unused41]
#
#
#
# word id 3 line = 4	慕熠凤	：	晴幻，你留下	[unused41]
# word id 2 line = 16	乔南辰	：	两个女孩吧！	[SEP]	可别给我来儿子了，有墨墨就足够了	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	您能有什么事？	[unused41]
#
#
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	咳咳，等大家来了再说	[unused41]
# word id 2 line = 17	夏玖晞	：	儿子不好嘛	[unused41]
#
#
# word id 0 line = 16	乔南辰	：	我们来了	[unused41]
#
# word id 2 line = 16	乔南辰	：	不是不好，男孩太皮了	[unused41]
# word id 0 line = 17	夏玖晞	：	倩倩，吴梁好久不见	[unused41]
#
# word id 0 line = 7	夏沫歌闺蜜【林倩倩】	：	玖晞啊！好久不见	[unused41]
#
#
# word id 0 line = 17	夏玖晞	：	嗯嗯	[unused41]
# word id 2 line = 17	夏玖晞	：	噗	[unused41]
#
# word id 3 line = 17	慕晴幻	：	我……	[unused41]
# word id 0 line = 16	乔南辰	：	吴梁，你叫我们有事吗？	[unused41]
#
#
#
# word id 2 line = 1	旁白	：	就在这个时候门铃响了。	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	在等下	[unused41]
#
# word id 3 line = 4	慕熠凤	：	听话	[unused41]
#
# word id 0 line = 17	夏玖晞	：	神神秘秘的	[unused41]
#
# word id 3 line = 17	慕晴幻	：	好吧	[unused41]
# word id 0 line = 13	乔逸晨哥们【吴梁】	：	哈哈	[unused41]
#
#
#
# word id 3 line = 3	乔南辰	：	舅舅，你想做什么？	[unused41]
# word id 2 line = 18	乔梓墨	：	干妈	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	灭了宋家	[unused41]
#
# word id 2 line = 7	夏沫歌闺蜜【林倩倩】	：	墨墨，我好想你	[SEP]	想我了吗？	[unused41]
# word id 3 line = 15	夏玖晞	：	……	[unused41]
#
#
# word id 3 line = 1	旁白	：	一句灭了宋家，惊呆了病房里的所有人	[unused41]
#
# word id 2 line = 18	乔梓墨	：	想啦！你都不来看我。	[unused41]
# word id 3 line = 7	夏玖晞妈妈	：	哥……这这不至于的	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	慕辞言，中毒的是你女儿，不是旁人	[SEP]	你不去，就让我这个舅舅去	[unused41]
#
# word id 2 line = 7	夏沫歌闺蜜【林倩倩】	：	哎呀，对不起啦，我这段时间都忘了	[unused41]
# word id 3 line = 7	夏玖晞妈妈	：	不是，哥我……	[unused41]
#
#
# word id 3 line = 4	慕熠凤	：	闭嘴	[unused41]
#
# word id 2 line = 18	乔梓墨	：	不跟你计较了	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	宝贝，你妈咪和你爸爸呢？	[unused41]
#
# word id 2 line = 18	乔梓墨	：	里面呢	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	哦哦	[unused41]
#
# word id 2 line = 18	乔梓墨	：	可以让妹妹跟我玩会儿吗？	[unused41]
#
# word id 2 line = 4	夏沫歌闺蜜【莫芸汐】	：	当然可以啦！	[SEP]	妹妹也想你了呢	[unused41]
#
# word id 2 line = 18	乔梓墨	：	那我带着妹妹去玩了，你们去聊天吧	[unused41]
#
# word id 2 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯	[unused41]
#
# word id 2 line = 1	旁白	：	乔梓墨抱着鹿妍熙上楼去房间玩耍，莫芸汐跟着林倩倩来到了大厅	[unused41]
#
# word id 2 line = 17	夏玖晞	：	倩倩，回来了？	[unused41]
#
# word id 2 line = 7	夏沫歌闺蜜【林倩倩】	：	嗯，玖晞	[SEP]	你胖了点	[unused41]
#
# word id 2 line = 17	夏玖晞	：	怀孕都这样	[SEP]	我是不是很丑？	[unused41]
#
# word id 2 line = 7	夏沫歌闺蜜【林倩倩】	：	不丑	[unused41]
